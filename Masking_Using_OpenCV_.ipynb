# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshbaskar1410/Machine-Learning-Projects/blob/main/Masking_Using_OpenCV_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Masking using OpenCV

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image_color = mpimg.imread('highway.jpg')                 #loading image

# %%
image_color.shape                                         #image shape, 3 denotes three channels
# Out:
# (900, 1200, 3)

# %%
plt.imshow(image_color)                                   # plotting the image

# %%
image_gray = cv2.cvtColor(image_color,cv2.COLOR_BGR2GRAY)              #  Converting colour image to gray


plt.imshow(image_gray,cmap='gray');
image_gray.shape
# Out:
# (900, 1200)

# %%
image_copy = np.copy(image_gray)
image_copy.shape
# Out:
# (900, 1200)

# %%
image_copy[ (image_copy[:,:] < 200)] = 1 # any value that is not white

# %%
#Display the image
plt.imshow(image_copy, cmap = 'gray')
plt.show()

# %% [markdown]
# -------------------

# %%
image_color = mpimg.imread('highway.jpg')

# %%
image_color.shape
# Out:
# (900, 1200, 3)

# %%
plt.imshow(image_color)

# %%
image_copy = np.copy(image_color)
image_copy.shape
# Out:
# (900, 1200, 3)

# %%
image_copy[(image_copy[:,:,0] < 200) | 
           (image_copy[:,:,1] < 180) | 
           (image_copy[:,:,2] < 100)] = 0

# %%
plt.imshow(image_copy, cmap = 'gray')
plt.show()

# %% [markdown]
# ## **PERFORM REGION OF INTEREST**

# %%
cv2.imshow('original image',image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
height, width, channels = image_color.shape

# %%
height, width = image_color.shape[:2]

# %%
height,width,channels
# Out:
# (900, 1200, 3)

# %%
plt.imshow(image_color)

# %%
ROI = np.array([[(45,height),(45,890),(260,750),(325,710),(434,655),(580,608),(775,590),(790,600),(820,590),(790,635),(1000,725),(1140,765),(1200,784),(width,height)]],dtype=np.int32) #These coordinates are found using hit and trail method
#define a blank image with all zeros (ie: black)
blank = np.zeros_like(image_gray)

# %%
# Fill the Region of interest with white color (ie: 255)!
mask = cv2.fillPoly(blank, ROI, 255)

# Perform bitwise AND operation to select only the region of interest
masked_image = cv2.bitwise_and(image_gray, mask)

# %%
masked_image.shape
# Out:
# (900, 1200)

# %%
plt.imshow(masked_image,cmap='gray')
